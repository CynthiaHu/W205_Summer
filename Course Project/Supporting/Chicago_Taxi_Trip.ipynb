# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install bokeh

import numpy as np
import pandas as pd
import datetime
import urllib
 
from bokeh.plotting import *
from bokeh.models import HoverTool
from collections import OrderedDict

# how much data do we read each time?
query = ("https://data.cityofchicago.org/resource/wrvz-psew.json")
raw_data = pd.read_json(query)

# %%
import csv
# taxi_csv_write=open('taxi_trip_sample.csv','wt')
# csvout = csv.writer(taxi_csv_write)
# csvout.write(raw_data)
# taxi_csv_write.close()
raw_data.to_csv('taxi_trip_sample.csv', sep=',')
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-12-f2841c97dc4f> in <module>()
#       2 taxi_csv_write=open('taxi_trip_sample.csv','wt')
#       3 csvout = csv.writer(taxi_csv_write)
# ----> 4 csvout.write(raw_data)
#       5 taxi_csv_write.close()
#
# AttributeError: '_csv.writer' object has no attribute 'write'

# %%
raw_data
# Out:
#      :@computed_region_vrxf_vc4k                            company  \
# 0                           29.0          Dispatch Taxi Affiliation
# 1                           31.0  Blue Ribbon Taxi Association Inc.
# 2                           37.0                                NaN
# 3                           37.0                                NaN
# 4                           19.0          Taxi Affiliation Services
# 5                           25.0            Choice Taxi Association
# 6                           68.0  Blue Ribbon Taxi Association Inc.
# 7                           37.0          Taxi Affiliation Services
# 8                           37.0          Taxi Affiliation Services
# 9                           37.0      Chicago Medallion Leasing INC
# 10                          38.0          Taxi Affiliation Services
# 11                          37.0  Blue Ribbon Taxi Association Inc.
# 12                          38.0                                NaN
# ...
