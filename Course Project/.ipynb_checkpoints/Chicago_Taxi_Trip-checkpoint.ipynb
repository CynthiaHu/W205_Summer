# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install bokeh

import numpy as np
import pandas as pd
import datetime
import urllib
 
from bokeh.plotting import *
from bokeh.models import HoverTool
from collections import OrderedDict

# how much data do we read each time?
query = ("https://data.cityofchicago.org/resource/wrvz-psew.json")
raw_data = pd.read_json(query)

# %%
raw_data.head()
# Out:
#    :@computed_region_vrxf_vc4k                    company  \
# 0                         53.0  Dispatch Taxi Affiliation
# 1                         68.0  Taxi Affiliation Services
# 2                         14.0      KOAM Taxi Association
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#    dropoff_census_tract  dropoff_centroid_latitude  \
# 0          1.703184e+10                  41.871016
# 1          1.703108e+10                  41.892042
# 2                   NaN                  42.001571
# 3                   NaN                        NaN
# 4                   NaN                        NaN
#
#                            dropoff_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.631407, ...
# 1  {'type': 'Point', 'coordinates': [-87.631864, ...
# 2  {'type': 'Point', 'coordinates': [-87.695013, ...
# 3                                                NaN
# 4                                                NaN
#
#    dropoff_centroid_longitude  dropoff_community_area  extras   fare  \
# 0                  -87.631407                    32.0     2.0  23.45
# 1                  -87.631864                     8.0     0.0   8.45
# 2                  -87.695013                     2.0     1.0   9.45
# 3                         NaN                     NaN     0.0   6.75
# 4                         NaN                     NaN     1.0   8.85
#
#   payment_type    ...      pickup_community_area  \
# 0  Credit Card    ...                       56.0
# 1         Cash    ...                        7.0
# 2         Cash    ...                       14.0
# 3  Credit Card    ...                        NaN
# 4         Cash    ...                        NaN
#
#                                              taxi_id  tips  tolls  \
# 0  11c10617d0c651e15a224f29ddccd39b777834546d2457...  5.05      0
# 1  e8872981b0207dc88bc7fc2778d1bf870967eb83ee03ac...  0.00      0
# 2  c8f2d4f28ea2a7d7fc9d8e55e2888dd72976ca3d3e3bef...  0.00      0
# 3  ac3197af61ac119894f5d339834595e2d1e28f8d6609e7...  1.50      0
# 4  8a0843b9d06ee98043a6dda41468b873f6abe47cd74676...  0.00      0
#
#         trip_end_timestamp                                   trip_id  \
# 0  2015-10-16T14:30:00.000  a8b69f55e37b5a5b53c8ab086e7eb577d63cafcf
# 1  2014-03-27T09:30:00.000  a8b69f68f8335c1dd11c3d04e20be58c5803afb3
# 2  2015-03-03T19:45:00.000  a8b69fe0a9971ea1db7b85706029913ba484cd35
# 3  2016-07-22T12:45:00.000  a8b6a01d793e3af40dd8f21e0d293aff3b193d85
# 4  2013-10-19T20:45:00.000  a8b6a02b09b5178e2168f3da54eba7d9d728b50c
#
#    trip_miles  trip_seconds     trip_start_timestamp trip_total
# 0         0.0        1560.0  2015-10-16T14:15:00.000      30.50
# 1         0.1         540.0  2014-03-27T09:30:00.000       8.45
# 2         3.2         720.0  2015-03-03T19:30:00.000      10.45
# 3         1.1         420.0  2016-07-22T12:30:00.000       8.75
# 4         2.9         540.0  2013-10-19T20:30:00.000       9.85
#
# [5 rows x 24 columns]
